# %% [markdown]
# This notebook has been used to generate some first tests using GX. It is based on the GX getting started docs. It is not intended to be run externally but only for generating the json configuration which can then be executed from CRON or Airflow.

# %%
import great_expectations as gx
import logging

# %%
import os
gx_context_root_dir=os.environ['GX_CONTEXT_ROOT_DIR']

# %%
context = gx.get_context(context_root_dir=gx_context_root_dir)
context.list_expectation_suites()
# Out:
# INFO:great_expectations.data_context.data_context.file_data_context:FileDataContext loading fluent config
# DEBUG:great_expectations.datasource.fluent.config:loaded from yaml ->
# {'anonymous_usage_statistics': {'data_context_id': '0b565257-5608-48e9-8b6d-8bbf5d4945d9',
#                                 'enabled': False},
#  'checkpoint_store_name': 'checkpoint_store',
#  'config_variables_file_path': 'uncommitted/config_variables.yml',
#  'config_version': 3.0,
#  'data_docs_sites': {'local_site': {'class_name': 'SiteBuilder',
#                                     'show_how_to_buttons': True,
#                                     'site_index_builder': {...},
#                                     'store_backend': {...}}},
#  'datasources': {},
#  'evaluation_parameter_store_name': 'evaluation_parameter_store',
#  'expectations_store_name': 'expectations_store',
#  'fluent_datasources': {'gfw-google-827': {'assets': {...},
#                                            'connection_string': 'bigquery://world-fishing-827/tech_great_expectations_temp_ttl_7d?credentials_path=/mnt/encrypted_data/git/api_keys/world-fishing-827-02584bdf5326.json',
#                                            'create_temp_table': True,
#                                            'type': 'sql'}},
#  'include_rendered_content': {'expectation_suite': False,
#                               'expectation_validation_result': False,
#                               'globally': False},
#  'notebooks': None,
#  'plugins_directory': 'plugins/',
#  'stores': {'checkpoint_store': {'class_name': 'CheckpointStore',
#                                  'store_backend': {...}},
#             'evaluation_parameter_store': {'class_name': 'EvaluationParameterStore'},
#             'expectations_store': {'class_name': 'ExpectationsStore',
#                                    'store_backend': {...}},
#             'profiler_store': {'class_name': 'ProfilerStore',
#                                'store_backend': {...}},
#             'validations_store': {'class_name': 'ValidationsStore',
#                                   'store_backend': {...}}},
#  'validations_store_name': 'validations_store'}
#
# INFO:great_expectations.datasource.fluent.config:Loading 'datasources' ->
# [{'assets': [...],
#   'connection_string': 'bigquery://world-fishing-827/tech_great_expectations_temp_ttl_7d?credentials_path=/mnt/encrypted_data/git/api_keys/world-fishing-827-02584bdf5326.json',
#   'create_temp_table': True,
#   'name': 'gfw-google-827',
#   'type': 'sql'}]
# DEBUG:great_expectations.datasource.fluent.config:Instantiating 'gfw-google-827' as <class 'great_expectations.datasource.fluent.sql_datasource.SQLDatasource'>
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages-3.0.0' asset ->
# QueryAsset(name='messages-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'messages', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_messages')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages-2.5' asset ->
# QueryAsset(name='messages-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_messages', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_messages')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'satellite_timing_offsets-3.0.0' asset ->
# QueryAsset(name='satellite_timing_offsets-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'satellite_timing_offsets', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'satellite_timing_offsets', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_satellite_timing_offsets')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'satellite_timing_offsets-2.5' asset ->
# QueryAsset(name='satellite_timing_offsets-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'satellite_timing_offsets', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_satellite_timing', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_satellite_timing')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segs_activity-3.0.0' asset ->
# QueryAsset(name='segs_activity-3.0.0', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'segs_activity', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'segs_activity', 'version_number': '3.0.0'}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_segs_activity')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segs_activity-2.5' asset ->
# QueryAsset(name='segs_activity-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segs_activity', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_segs', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_segs')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segs_activity_daily-3.0.0' asset ->
# QueryAsset(name='segs_activity_daily-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segs_activity_daily', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'segs_activity_daily', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_segs_activity_daily')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segs_activity_daily-2.5' asset ->
# QueryAsset(name='segs_activity_daily-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segs_activity_daily', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_segs_daily', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_segs_daily')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'ssvids_identities-3.0.0' asset ->
# QueryAsset(name='ssvids_identities-3.0.0', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'ssvids_identities', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'ssvids_identities', 'version_number': '3.0.0'}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_ssvids_identities')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'ssvids_identities-2.5' asset ->
# QueryAsset(name='ssvids_identities-2.5', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'ssvids_identities', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_ids', 'version_number': 2.5}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_ids')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'ssvids_identities_daily-3.0.0' asset ->
# QueryAsset(name='ssvids_identities_daily-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'ssvids_identities_daily', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'ssvids_identities_daily', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_ssvids_identities_daily')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'ssvids_identities_daily-2.5' asset ->
# QueryAsset(name='ssvids_identities_daily-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'ssvids_identities_daily', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_ids_daily', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_ids_daily')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'stats_daily-3.0.0' asset ->
# QueryAsset(name='stats_daily-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'stats_daily', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'stats_daily', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_stats_daily')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'stats_daily-2.5' asset ->
# QueryAsset(name='stats_daily-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'stats_daily', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_stats', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_stats')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'vessel_info-3.0.0' asset ->
# QueryAsset(name='vessel_info-3.0.0', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'vessel_info', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'vessel_info', 'version_number': '3.0.0'}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_vessel_info')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'vessel_info-2.5' asset ->
# QueryAsset(name='vessel_info-2.5', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'vessel_info', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'vessel_info', 'version_number': 2.5}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_vessel_info')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'features_-3.0.0' asset ->
# QueryAsset(name='features_-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'features_', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'features_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_features_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'features_-2.5' asset ->
# QueryAsset(name='features_-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'features_', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'features_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_features_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'fishing_score_-3.0.0' asset ->
# QueryAsset(name='fishing_score_-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'fishing_score_', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'fishing_score_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_fishing_score_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'fishing_score_-2.5' asset ->
# QueryAsset(name='fishing_score_-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'fishing_score_', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'fishing_score_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_fishing_score_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'fragments-3.0.0' asset ->
# QueryAsset(name='fragments-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'fragments', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'fragments_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_fragments_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages_positions-3.0.0' asset ->
# QueryAsset(name='messages_positions-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages_positions', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'messages_positions', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_messages_positions')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages_positions-2.5' asset ->
# QueryAsset(name='messages_positions-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages_positions', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'position_messages_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_position_messages_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages_scored_-3.0.0' asset ->
# QueryAsset(name='messages_scored_-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages_scored_', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'messages_scored_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_messages_scored_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages_scored_-2.5' asset ->
# QueryAsset(name='messages_scored_-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages_scored_', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'messages_scored_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_messages_scored_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages_segmented_-3.0.0' asset ->
# QueryAsset(name='messages_segmented_-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages_segmented_', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'messages_segmented_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_messages_segmented_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'messages_segmented_-2.5' asset ->
# QueryAsset(name='messages_segmented_-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages_segmented_', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'messages_segmented_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_messages_segmented_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_identity_daily_-3.0.0' asset ->
# QueryAsset(name='segment_identity_daily_-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segment_identity_daily_', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'segment_identity_daily_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_segment_identity_daily_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_identity_daily_-2.5' asset ->
# QueryAsset(name='segment_identity_daily_-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segment_identity_daily_', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'segment_identity_daily_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_segment_identity_daily_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_info-3.0.0' asset ->
# QueryAsset(name='segment_info-3.0.0', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'segment_info', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'segment_info', 'version_number': '3.0.0'}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_segment_info')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_info-2.5' asset ->
# QueryAsset(name='segment_info-2.5', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'segment_info', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'segment_info', 'version_number': 2.5}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_segment_info')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_vessel-3.0.0' asset ->
# QueryAsset(name='segment_vessel-3.0.0', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'segment_vessel', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'segment_vessel', 'version_number': '3.0.0'}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_segment_vessel')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_vessel-2.5' asset ->
# QueryAsset(name='segment_vessel-2.5', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'segment_vessel', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'segment_vessel', 'version_number': 2.5}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_segment_vessel')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_vessel_daily_-3.0.0' asset ->
# QueryAsset(name='segment_vessel_daily_-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segment_vessel_daily_', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'segment_vessel_daily_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_segment_vessel_daily_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segment_vessel_daily_-2.5' asset ->
# QueryAsset(name='segment_vessel_daily_-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segment_vessel_daily_', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'segment_vessel_daily_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_segment_vessel_daily_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segments-3.0.0' asset ->
# QueryAsset(name='segments-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segments', 'dataset_name': 'pipe_ais_v3_alpha_internal', 'table_name': 'segments_', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_internal_segments_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'segments-2.5' asset ->
# QueryAsset(name='segments-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segments', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'segments_', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_segments_')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'encounters-3.0.0' asset ->
# QueryAsset(name='encounters-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'encounters', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'encounters', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_encounters')
# DEBUG:great_expectations.datasource.fluent.interfaces:Loading 'encounters-2.5' asset ->
# QueryAsset(name='encounters-2.5', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'encounters', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'encounters', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_encounters')
# DEBUG:great_expectations.datasource.fluent.config:Loaded 'datasources' ->
# [SQLDatasource(type='sql', name='gfw-google-827', id=None, assets=[QueryAsset(name='messages-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'messages', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_messages'), QueryAsset(name='messages-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'messages', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_messages', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_messages'), QueryAsset(name='satellite_timing_offsets-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'satellite_timing_offsets', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'satellite_timing_offsets', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_satellite_timing_offsets'), QueryAsset(name='satellite_timing_offsets-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'satellite_timing_offsets', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_satellite_timing', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_satellite_timing'), QueryAsset(name='segs_activity-3.0.0', type='query', id=None, order_by=[], batch_metadata={'datasource_name': 'segs_activity', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'segs_activity', 'version_number': '3.0.0'}, splitter=None, query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_segs_activity'), QueryAsset(name='segs_activity-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segs_activity', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_segs', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_segs'), QueryAsset(name='segs_activity_daily-3.0.0', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segs_activity_daily', 'dataset_name': 'pipe_ais_v3_alpha_published', 'table_name': 'segs_activity_daily', 'version_number': '3.0.0'}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_ais_v3_alpha_published_segs_activity_daily'), QueryAsset(name='segs_activity_daily-2.5', type='query', id=None, order_by=[Sorter(key='SPLITTER_COLUMN', reverse=True)], batch_metadata={'datasource_name': 'segs_activity_daily', 'dataset_name': 'pipe_production_v20201001', 'table_name': 'research_segs_daily', 'version_number': 2.5}, splitter=SplitterColumnValue(column_name='SPLITTER_COLUMN', method_name='split_on_column_value'), query='SELECT * FROM tech_great_expectations_temp_ttl_7d.v_unfiltered_pipe_production_v20201001_research_segs_daily'), QueryAsset(name='ssvids_identities-3.0.0', type='query', id=None, order ...
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.store.store:Building store_backend.
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.store.store:Building store_backend.
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.store.store:Building store_backend.
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.store.store:Building store_backend.
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.store.store:Building store_backend.
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# DEBUG:great_expectations.data_context.store.store:Building store_backend.
# DEBUG:great_expectations.data_context.util:(instantiate_class_from_config) module_name -> great_expectations.data_context.store
# INFO:great_expectations.data_context.data_context.abstract_data_context:Usage statistics is disabled; skipping initialization.
# INFO:great_expectations.data_context.data_context.abstract_data_context:Loaded 'gfw-google-827' from fluent config
# DEBUG:great_expectations.data_context.data_context.file_data_context:Starting DataContext._save_project_config; attempting to update /mnt/encrypted_data/git/data-testing/great_expectations/great_expectations.yml
# INFO:great_expectations.data_context.data_context.file_data_context:Saving 1 Fluent Datasources to /mnt/encrypted_data/git/data-testing/great_expectations/great_expectations.yml
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:GxConfig.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.__fields_set__ assets added
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:QueryAsset.__fields_set__ assets discarded
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SplitterColumnValue.__fields_set__ assets discarded
# [ExpectationSuiteIdentifier::gfw-google-827.constraints.segs_activity.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segs_activity.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.encounters.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.encounters.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.features_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.features_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.ssvids_identities.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.ssvids_identities.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.fishing_score_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.fishing_score_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segs_activity.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segs_activity.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_identity_daily_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_identity_daily_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_info.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages_scored_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages_scored_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.fishing_score_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.fishing_score_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_vessel.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_vessel.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segs_activity_daily.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segs_activity_daily.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_vessel_daily_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_vessel_daily_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.features_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.features_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.stats_daily.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.stats_daily.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segments.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segments.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_info.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.stats_daily.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.stats_daily.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.fragments.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.fragments.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_vessel.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_vessel.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.vessel_info.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.vessel_info.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.encounters.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.encounters.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages_segmented_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages_segmented_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages_scored_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages_scored_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_info.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_info.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.ssvids_identities_daily.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.ssvids_identities_daily.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.ssvids_identities_daily.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.ssvids_identities_daily.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.satellite_timing_offsets.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.satellite_timing_offsets.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.vessel_info.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.vessel_info.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_vessel_daily_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_vessel_daily_.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segments.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segments.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.ssvids_identities.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.ssvids_identities.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segment_identity_daily_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segment_identity_daily_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages_positions.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages_positions.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.satellite_timing_offsets.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.satellite_timing_offsets.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages_segmented_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages_segmented_.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.messages_positions.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.messages_positions.3-0-0,
#  ExpectationSuiteIdentifier::gfw-google-827.constraints.segs_activity_daily.2-5,
#  ExpectationSuiteIdentifier::gfw-google-827.alerts.segs_activity_daily.2-5]

# %%
import yaml

# %%
from datetime import date,datetime

# %%
logging.basicConfig(level=logging.DEBUG, force = True)

# %%
with open(f"{gx_context_root_dir}/datasources/datasources.yml", "r") as ymlfile:
    datasource_config = yaml.full_load(ymlfile)

# %%
datasource_config.get("project")
# Out:
# 'gfw-google-827'

# %%
gx_project = datasource_config.get("project")
gx_datasource = context.get_datasource(gx_project)

# %%
gx_datasource.get_asset_names()
# Out:
# {'encounters-2.5',
#  'encounters-3.0.0',
#  'features_-2.5',
#  'features_-3.0.0',
#  'fishing_score_-2.5',
#  'fishing_score_-3.0.0',
#  'fragments-3.0.0',
#  'messages-2.5',
#  'messages-3.0.0',
#  'messages_positions-2.5',
#  'messages_positions-3.0.0',
#  'messages_scored_-2.5',
#  'messages_scored_-3.0.0',
#  'messages_segmented_-2.5',
#  'messages_segmented_-3.0.0',
#  'satellite_timing_offsets-2.5',
#  'satellite_timing_offsets-3.0.0',
#  'segment_identity_daily_-2.5',
#  'segment_identity_daily_-3.0.0',
#  'segment_info-2.5',
#  'segment_info-3.0.0',
#  'segment_vessel-2.5',
#  'segment_vessel-3.0.0',
#  'segment_vessel_daily_-2.5',
#  'segment_vessel_daily_-3.0.0',
#  'segments-2.5',
#  'segments-3.0.0',
#  'segs_activity-2.5',
#  'segs_activity-3.0.0',
#  'segs_activity_daily-2.5',
#  'segs_activity_daily-3.0.0',
#  'ssvids_identities-2.5',
#  'ssvids_identities-3.0.0',
#  'ssvids_identities_daily-2.5',
#  'ssvids_identities_daily-3.0.0',
#  'stats_daily-2.5',
#  'stats_daily-3.0.0',
#  'vessel_info-2.5',
#  'vessel_info-3.0.0'}

# %%
context.list_expectation_suite_names()
# Out:
# ['gfw-google-827.alerts.encounters.2-5',
#  'gfw-google-827.alerts.encounters.3-0-0',
#  'gfw-google-827.alerts.features_.2-5',
#  'gfw-google-827.alerts.features_.3-0-0',
#  'gfw-google-827.alerts.fishing_score_.2-5',
#  'gfw-google-827.alerts.fishing_score_.3-0-0',
#  'gfw-google-827.alerts.fragments.3-0-0',
#  'gfw-google-827.alerts.messages.2-5',
#  'gfw-google-827.alerts.messages.3-0-0',
#  'gfw-google-827.alerts.messages_positions.2-5',
#  'gfw-google-827.alerts.messages_positions.3-0-0',
#  'gfw-google-827.alerts.messages_scored_.2-5',
#  'gfw-google-827.alerts.messages_scored_.3-0-0',
#  'gfw-google-827.alerts.messages_segmented_.2-5',
#  'gfw-google-827.alerts.messages_segmented_.3-0-0',
#  'gfw-google-827.alerts.satellite_timing_offsets.2-5',
#  'gfw-google-827.alerts.satellite_timing_offsets.3-0-0',
#  'gfw-google-827.alerts.segment_identity_daily_.2-5',
#  'gfw-google-827.alerts.segment_identity_daily_.3-0-0',
#  'gfw-google-827.alerts.segment_info.2-5',
#  'gfw-google-827.alerts.segment_info.3-0-0',
#  'gfw-google-827.alerts.segment_vessel.2-5',
#  'gfw-google-827.alerts.segment_vessel.3-0-0',
#  'gfw-google-827.alerts.segment_vessel_daily_.2-5',
#  'gfw-google-827.alerts.segment_vessel_daily_.3-0-0',
#  'gfw-google-827.alerts.segments.2-5',
#  'gfw-google-827.alerts.segments.3-0-0',
#  'gfw-google-827.alerts.segs_activity.2-5',
#  'gfw-google-827.alerts.segs_activity.3-0-0',
#  'gfw-google-827.alerts.segs_activity_daily.2-5',
#  'gfw-google-827.alerts.segs_activity_daily.3-0-0',
#  'gfw-google-827.alerts.ssvids_identities.2-5',
#  'gfw-google-827.alerts.ssvids_identities.3-0-0',
#  'gfw-google-827.alerts.ssvids_identities_daily.2-5',
#  'gfw-google-827.alerts.ssvids_identities_daily.3-0-0',
#  'gfw-google-827.alerts.stats_daily.2-5',
#  'gfw-google-827.alerts.stats_daily.3-0-0',
#  'gfw-google-827.alerts.vessel_info.2-5',
#  'gfw-google-827.alerts.vessel_info.3-0-0',
#  'gfw-google-827.constraints.encounters.2-5',
#  'gfw-google-827.constraints.encounters.3-0-0',
#  'gfw-google-827.constraints.features_.2-5',
#  'gfw-google-827.constraints.features_.3-0-0',
#  'gfw-google-827.constraints.fishing_score_.2-5',
#  'gfw-google-827.constraints.fishing_score_.3-0-0',
#  'gfw-google-827.constraints.fragments.3-0-0',
#  'gfw-google-827.constraints.messages.2-5',
#  'gfw-google-827.constraints.messages.3-0-0',
#  'gfw-google-827.constraints.messages_positions.2-5',
#  'gfw-google-827.constraints.messages_positions.3-0-0',
#  'gfw-google-827.constraints.messages_scored_.2-5',
#  'gfw-google-827.constraints.messages_scored_.3-0-0',
#  'gfw-google-827.constraints.messages_segmented_.2-5',
#  'gfw-google-827.constraints.messages_segmented_.3-0-0',
#  'gfw-google-827.constraints.satellite_timing_offsets.2-5',
#  'gfw-google-827.constraints.satellite_timing_offsets.3-0-0',
#  'gfw-google-827.constraints.segment_identity_daily_.2-5',
#  'gfw-google-827.constraints.segment_identity_daily_.3-0-0',
#  'gfw-google-827.constraints.segment_info.2-5',
#  'gfw-google-827.constraints.segment_info.3-0-0',
#  'gfw-google-827.constraints.segment_vessel.2-5',
#  'gfw-google-827.constraints.segment_vessel.3-0-0',
#  'gfw-google-827.constraints.segment_vessel_daily_.2-5',
#  'gfw-google-827.constraints.segment_vessel_daily_.3-0-0',
#  'gfw-google-827.constraints.segments.2-5',
#  'gfw-google-827.constraints.segments.3-0-0',
#  'gfw-google-827.constraints.segs_activity.2-5',
#  'gfw-google-827.constraints.segs_activity.3-0-0',
#  'gfw-google-827.constraints.segs_activity_daily.2-5',
#  'gfw-google-827.constraints.segs_activity_daily.3-0-0',
#  'gfw-google-827.constraints.ssvids_identities.2-5',
#  'gfw-google-827.constraints.ssvids_identities.3-0-0',
#  'gfw-google-827.constraints.ssvids_identities_daily.2-5',
#  'gfw-google-827.constraints.ssvids_identities_daily.3-0-0',
#  'gfw-google-827.constraints.stats_daily.2-5',
#  'gfw-google-827.constraints.stats_daily.3-0-0',
#  'gfw-google-827.constraints.vessel_info.2-5',
#  'gfw-google-827.constraints.vessel_info.3-0-0']

# %%
TABLE_NAME = "_______PUT_TABLE_NAME_HERE_AS_A_STRING_______"
DUMMY_BATCH_DATE = '2023-04-01' # the date slice you want to run interactive expectations on

# %%
for current_expectation_suite_name in [es for es in context.list_expectation_suite_names() if TABLE_NAME in es and 'constraints' in es]:
    print(current_expectation_suite_name)
    current_expectation_suite=context.get_expectation_suite(current_expectation_suite_name)    
    current_expectation_suite_asset_name=current_expectation_suite.meta.get('asset_name')
    current_expectation_suite_datasource_name=current_expectation_suite.meta.get('datasource_name')
    current_expectation_suite_version_number=current_expectation_suite.meta.get('version_number')

    gx_asset=gx_datasource.get_asset(current_expectation_suite_asset_name)
    gx_splitter=gx_asset.splitter
    if gx_splitter is not None:
        DATE_PARTITION_COLUMN=gx_splitter.column_name
        br_options={DATE_PARTITION_COLUMN: DUMMY_BATCH_DATE}
    else:
        br_options={}
    gx_br = gx_asset.build_batch_request(br_options)
    gx_batches = gx_datasource.get_batch_list_from_batch_request(gx_br)
    gx_validator = context.get_validator_using_batch_list(current_expectation_suite, gx_batches)

    # gx_validator.expect_column_values_to_be_unique('seg_id')
    # gx_validator.expect_column_values_to_not_be_null('seg_id')

    # hours_cols = [hours_col for hours_col in gx_validator.columns() if 'hour' in hours_col and not '.' in hours_col]
    # for current_hours_col in hours_cols:
    #     gx_validator.expect_column_values_to_be_between(
    #         column=current_hours_col, 
    #         min_value=0, 
    #         max_value=48, 
    #         strict_max=True
    #     )
    #     if current_hours_col != 'hours':
    #         gx_validator.expect_column_pair_values_a_to_be_greater_than_b(
    #             'hours', current_hours_col, or_equal=True
    #         )

    # if some expectations fail "as expected" leaves this False
    # setting discard_failed_expectations=True could be useful when experimenting a lot
    gx_validator.save_expectation_suite(discard_failed_expectations=False)
# Out:
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.__fields_set__ assets added
# INFO:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.dict() - substituting config values
# DEBUG:urllib3.util.retry:Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# DEBUG:google.auth.transport.requests:Making request: POST https://oauth2.googleapis.com/token
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oauth2.googleapis.com:443
# gfw-google-827.constraints.segs_activity_daily.2-5
# DEBUG:urllib3.connectionpool:https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): bigquery.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/5e6f297b-b655-42d3-bb78-d75590657d0a?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/jobs/5e6f297b-b655-42d3-bb78-d75590657d0a?location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.__fields_set__ assets added
# INFO:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.dict() - substituting config values
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/2ed731df-dddc-4d58-8d6a-e2560186c0a1?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:google.api_core.retry:Retrying due to , sleeping 0.6s ...
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/2ed731df-dddc-4d58-8d6a-e2560186c0a1?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/jobs/2ed731df-dddc-4d58-8d6a-e2560186c0a1?location=US&prettyPrint=false HTTP/1.1" 200 None
# INFO:great_expectations.datasource.data_connector.batch_filter:batch_slice: None was parsed to: slice(0, None, None)
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/adc9db99-0fe5-4e46-a614-519472fc0de9?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/301a4d5e-306b-4ed2-8c11-16ff18db91fb?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/jobs/301a4d5e-306b-4ed2-8c11-16ff18db91fb?location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/9bb99d6c-37ab-48ce-a02f-b290dfd81d93?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/jobs/9bb99d6c-37ab-48ce-a02f-b290dfd81d93?location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (seg_id IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/140705e1-3fb5-401e-b0ab-994570bf50e4?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/64d7f6a0-107a-4ada-bbf6-f1cb356cf3df?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/f26452f9-a113-4c0a-89cb-05bc4f489d25?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (seg_id IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/c8255921-64ef-4b12-a0a4-a24447be33af?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/2088ec19-c7db-4955-a1e9-d90c117cfc67?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/8282cb51-eed3-4874-bd4f-72556477f314?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (hours IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count", sum(CASE WHEN (hours IS NOT NULL AND NOT (hours >= :param_3 AND hours < :param_4)) THEN :param_5 ELSE :param_6 END) AS "column_values.between.unexpected_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/e4ea68fa-6c38-4d28-9197-9d408954372e?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/7a7e5116-284a-4d91-9fa7-abdf029d3c33?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/8fabff10-1064-472b-bcf8-5bd20ae4f4bb?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (active_hours IS NOT NULL AND NOT (active_hours >= :param_1 AND active_hours < :param_2)) THEN :param_3 ELSE :param_4 END) AS "column_values.between.unexpected_count", sum(CASE WHEN (active_hours IS NULL) THEN :param_5 ELSE :param_6 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/595b0f52-dbdc-446e-95a7-39c7ce730d23?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/88ae0f26-1944-442b-bb90-cccb9f8a2b32?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/b295d73c-0704-40ce-8d5b-a063e60ff1a8?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/265fbe94-b8c7-4f69-8a29-faeaf2330c47?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/ce70229c-a088-4699-8492-35c0eca8cb42?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/610dabe5-f799-424e-be22-ac3ca3743eb0?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/cfe3ed5e-7092-404b-9457-602953e4234f?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (fishing_hours IS NOT NULL AND NOT (fishing_hours >= :param_1 AND fishing_hours < :param_2)) THEN :param_3 ELSE :param_4 END) AS "column_values.between.unexpected_count", sum(CASE WHEN (fishing_hours IS NULL) THEN :param_5 ELSE :param_6 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/836ad571-8a31-41e8-a06c-908fd88e8a68?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/c1c0ba71-27d8-4330-b399-147ee8cff565?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/71208e74-7729-417c-9980-61b1f1fb8145?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/c52e62e1-3260-4591-a268-20f6d33bcc8f?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/ee97fb4f-a281-4edc-9c10-f163c8383742?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/0e8ed970-707e-4cc0-99e8-cc85fbbe82d1?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/53679112-f5ed-44b5-a8b4-c2ad93c42431?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (night_loitering_hours IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count", sum(CASE WHEN (night_loitering_hours IS NOT NULL AND NOT (night_loitering_hours >= :param_3 AND night_loitering_hours < :param_4)) THEN :param_5 ELSE :param_6 END) AS "column_values.between.unexpected_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/82d3b81e-e552-496d-926a-8844f4df15ea?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/16006480-f48d-489f-a44a-36b888e2a552?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/16a5c93b-2cd4-4c6e-a3c6-753322d6c34c?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/ebeabbbc-edcb-4f14-9572-f6ba4fcb70da?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/4f2500f1-22e9-40f2-bbdc-9c4b7e061ae3?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/458e1780-6a25-403a-9c66-fd581b948178?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/366ac05f-94fd-4c56-a916-fecdaa7b8c3c?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (port_hours IS NOT NULL AND NOT (port_hours >= :param_1 AND port_hours < :param_2)) THEN :param_3 ELSE :param_4 END) AS "column_values.between.unexpected_count", sum(CASE WHEN (port_hours IS NULL) THEN :param_5 ELSE :param_6 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/e543138d-1db6-4597-88d8-d0c0074ec5f5?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_947b73f5?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_947b73f5
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/4e14b2c8-f0ba-4062-82b5-32831288cee9?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id fcd7b271825e6f55f45e576d1d9f741b
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/ee83cfd8-b812-46e1-aab9-ca6a37de8d12?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/56d168a8-e00b-4f84-9780-04042c049fe0?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/e375baa8-dc56-4beb-ae7b-4fc593906c74?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# INFO:great_expectations.validator.validator:	11 expectation(s) included in expectation_suite.
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.__fields_set__ assets added
# INFO:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.dict() - substituting config values
# gfw-google-827.constraints.segs_activity_daily.3-0-0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/e5279dfd-da1b-4ac5-8ce1-45819d060032?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.__fields_set__ assets added
# INFO:great_expectations.datasource.fluent.fluent_base_model:SQLDatasource.dict() - substituting config values
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/c63f477a-8acb-4d92-aca6-4a53bec32b8c?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/jobs/c63f477a-8acb-4d92-aca6-4a53bec32b8c?location=US&prettyPrint=false HTTP/1.1" 200 None
# INFO:great_expectations.datasource.data_connector.batch_filter:batch_slice: None was parsed to: slice(0, None, None)
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/727e174d-d9f4-4167-999a-dba101f82f86?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/eaa7f038-a7ee-425e-9778-69c5302dfc64?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/jobs/eaa7f038-a7ee-425e-9778-69c5302dfc64?location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/c104a99f-a15a-46c6-a4f9-f6149a28fc12?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/jobs/c104a99f-a15a-46c6-a4f9-f6149a28fc12?location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (seg_id IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/9397a955-25e7-4399-82d6-1f45963fbf21?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/61468f9d-8865-437c-94a5-3a0df84c39bb?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/87d27b64-4c0e-4b7b-8802-2616c2acb19f?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (seg_id IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/d4d4d34b-82b0-4bda-89f6-a3f4fc59c2d9?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/b309573f-67bc-419e-a2b6-a1d9fe002976?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/d689581c-a382-4144-a503-b34f8807348c?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (hours IS NOT NULL AND NOT (hours >= :param_1 AND hours < :param_2)) THEN :param_3 ELSE :param_4 END) AS "column_values.between.unexpected_count", sum(CASE WHEN (hours IS NULL) THEN :param_5 ELSE :param_6 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/e602483a-58d6-4841-aa74-35b5bfbb558e?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/dcd2b155-b788-45c3-9ff6-c96c18c45a42?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/05eb10cf-8064-41b4-a329-6a63df4e3e6b?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (active_hours IS NOT NULL AND NOT (active_hours >= :param_1 AND active_hours < :param_2)) THEN :param_3 ELSE :param_4 END) AS "column_values.between.unexpected_count", sum(CASE WHEN (active_hours IS NULL) THEN :param_5 ELSE :param_6 END) AS "column_values.nonnull.unexpected_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/665783d5-07a9-4018-b11c-d021060c1fc4?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/db9670b0-4922-47cf-aac2-394b8be3f1b4?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/88b760c1-b7e2-4820-b58d-181170ba84d4?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/68ca86ed-a569-4725-91a7-61799d963e78?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/7823542b-36bf-4aeb-b95d-5456052edc7b?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/57364e2c-5ec9-4272-ae95-4af8b7b6bcad?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/633b174d-71a6-4c67-a257-229c0001eec0?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (fishing_hours IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count", sum(CASE WHEN (fishing_hours IS NOT NULL AND NOT (fishing_hours >= :param_3 AND fishing_hours < :param_4)) THEN :param_5 ELSE :param_6 END) AS "column_values.between.unexpected_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/610b2972-1410-4bc3-834d-6a89854a9c59?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/dbaf7f91-4f35-4df0-803b-7ee37aaeae81?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/4cb6b222-44c5-47b2-b8a9-f21ab6d02b2b?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/a4f584b0-d6e0-4f73-aa94-d20fca9dc6be?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/6ab6c2e8-8ef1-407f-ab1e-bab3f866b119?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/9d66e698-da6d-4b85-bdc3-045db1d370e1?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/a57690ea-93a9-4c85-819a-81ebb2920223?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (night_loitering_hours IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count", sum(CASE WHEN (night_loitering_hours IS NOT NULL AND NOT (night_loitering_hours >= :param_3 AND night_loitering_hours < :param_4)) THEN :param_5 ELSE :param_6 END) AS "column_values.between.unexpected_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/52ffeaa4-d8e8-413a-ac2c-087969d01446?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/afc0bffc-f8e0-40dc-9ccb-ba870e479ecb?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/88f9f24f-32be-4415-9312-5fc18009a627?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/59dcf05c-307a-4da4-9029-39f35c4b005d?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/f61e438b-5058-42a9-b324-3ee30134373f?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/b5151192-883b-43fd-80b1-8b258ba70137?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/b2a83680-723d-46c9-9322-b7756df7ab96?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT sum(CASE WHEN (port_hours IS NULL) THEN :param_1 ELSE :param_2 END) AS "column_values.nonnull.unexpected_count", sum(CASE WHEN (port_hours IS NOT NULL AND NOT (port_hours >= :param_3 AND port_hours < :param_4)) THEN :param_5 ELSE :param_6 END) AS "column_values.between.unexpected_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/9288b2db-77ab-4e47-b533-6c86d41f4890?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 2 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:great_expectations.core.expectation_configuration:evaluation_parameters have already been built on this expectation
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/datasets/tech_great_expectations_temp_ttl_7d/tables/gx_temp_ef84cac6?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:Attempting query SELECT count(*) AS "table.row_count"
# FROM gx_temp_ef84cac6
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/ce94ce06-be01-4b10-baab-24bedc4046f1?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:great_expectations.execution_engine.sqlalchemy_execution_engine:SqlAlchemyExecutionEngine computed 1 metrics on domain_id 68ad50c45a5c01c0afa39f9a74f224d0
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/718a21e9-1a00-41d9-8444-d969c100113f?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/d10a76cd-f75f-477d-904f-40c4e95343ef?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/world-fishing-827/jobs?prettyPrint=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/world-fishing-827/queries/c95424d0-f4f6-47f5-a929-827c1f595363?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# INFO:great_expectations.validator.validator:	11 expectation(s) included in expectation_suite.
